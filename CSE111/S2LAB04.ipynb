# %%
 #TASK01
class Customer:
  def __init__(self,name = None):
    self.name = name

  def greet(self,name = None):
    if name == None:
      print("Hello!")
      print()
    else:
      print("Hello ",name," !")
      print()

  def purchase (self,*args):
     print(f"{self.name}, you have purchased {len(args)} item(s)")
     print()
     for i in args:
       print(i)
       print()

customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
#
# Sam, you have purchased 3 item(s)
#
# chips
#
# chocolate
#
# orange juice
#
# -----------------------------
# Hello  David  !
#
# David, you have purchased 1 item(s)
#
# orange juice

# %%
#TASK02
class Panda:
  def __init__(self,name,gender,age):
    self.name = name
    self.age = age
    self.gender = gender

  def sleep(self,hours = None):
    if hours == None:
      return f"{self.name} duration is unknown thus should have only  bamboo leaves"
    elif 3<=hours<=5:
      return f"{self.name} sleeps {hours} hours daily and should have Mixed Veggies"
    elif 6<=hours<=8:
      return f"{self.name} sleeps {hours} hours daily and should have Eggplant & Tofu"
    elif 9<=hours<=11:
      return f"{self.name} sleeps {hours} hours daily and should have Broccoli Chicken"



panda1 = Panda("Kunfu","Male", 5)
panda2=Panda("Pan Pan","Female",3)
panda3=Panda("Ming Ming","Female",8)

print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))

print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))

print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))

print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming duration is unknown thus should have only  bamboo leaves

# %%
#TASK03
class Cat:
  def __init__(self,color = "White",work = "sitting" ):
    self.color = color
    self.work = work
  def printCat(self):
    print(f"{self.color} cat is {self.work}")
  def changeColor(self,change):
    self.color = change

c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#TASK04
class Student:
  def __init__(self,name = "default student"):
    self.name = name
  def quizcalc(self,quiz1 = 0,quiz2 = 0, quiz3 = 0):
    self.avg = (quiz1+quiz2+quiz3)/3
  def printdetail(self):
    print("Hello ",self.name)
    print("Your average quiz score is ",self.avg)

s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Out:
# --------------------------------
# Hello  default student
# Your average quiz score is  3.3333333333333335
# --------------------------------
# Hello  Harry
# Your average quiz score is  6.0
# --------------------------------
# Hello  Hermione
# Your average quiz score is  9.666666666666666

# %%
#TASK05
class Student:
  def __init__(self,name, id, dep = "CSE"):
    self.name = name
    self.id = id
    self.dep = dep
  def dailyEffort(self,hours):
    self.hours = hours
  def printDetails(self):
    print("Name: ",self.name)
    print("ID: ",self.id)
    print("Department:", self.dep)
    print("Daily Effort: ",self.hours,"hour(s)")
    if 0<=self.hours<=2:
      print("Should give more effort!")
    elif 2<self.hours<=4:
      print("Keep up the good work!")
    else:
      print("Excellent! Now motivate others.")

harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name:  Harry Potter
# ID:  123
# Department: CSE
# Daily Effort:  3 hour(s)
# Keep up the good work!
# ...
# Name:  John Wick
# ID:  456
# Department: BBA
# Daily Effort:  2 hour(s)
# Should give more effort!
# ...
# Name:  Naruto Uzumaki
# ID:  777
# Department: Ninja
# Daily Effort:  6 hour(s)
# Excellent! Now motivate others.

# %%
#TASK06
class Patient:
  def __init__(self, name, age):
    self.name = name
    self.age = age
  def add_Symptom(self,*args):
    self.symp = ""
    for i in args:
      if i == args[len(args)-1]:
        self.symp+=i
      else:
        self.symp+=i+","+" "
  def printPatientDetail(self):
    print("Name: ",self.name)
    print("Age: ",self.age)
    print("Symptoms:",self.symp)

p1 = Patient("Thomas", 23)
p1.add_Symptom("Headache")
p2 = Patient("Carol", 20)
p2.add_Symptom("Vomiting", "Coughing")
p3 = Patient("Mike", 25)
p3.add_Symptom("Fever", "Headache", "Coughing")
print("=========================")
p1.printPatientDetail()
print("=========================")
p2.printPatientDetail()
print("=========================")
p3.printPatientDetail()
# Out:
# ...
# Name:  Thomas
# Age:  23
# Symptoms: Headache
# ...
# Name:  Carol
# Age:  20
# Symptoms: Vomiting, Coughing
# ...
# Name:  Mike
# Age:  25
# Symptoms: Fever, Headache, Coughing

# %%
#TASK07
class Match:
  def __init__(self,name):
    self.name = name.split("-")
    self.bat = self.name[0]
    self.bowl = self.name[1]
    self.run = 0
    self.over = 0
    self.wicket = 0
    print("5..4..3..2..1.. Play !!!")

  def add_run(self,run):
    self.run += run
  def add_over(self,over):
    self.over += over
    if self.over>5:
      print(f"Warning! Cannot add {over} over/s (5 over match)")
      self.over -= over


  def add_wicket(self,wicket):
    self.wicket += wicket

  def print_scoreboard(self):
    return f"Batting Team: {self.bat}\nBowling Team: {self.bowl}\nTotal Runs: {self.run} Wickets: {self.wicket} Overs: {self.over}"

match1 = Match("Rangpur Riders-Cumilla Victorians")
print("=========================")
match1.add_run(4)
match1.add_run(6)
match1.add_over(1)
print(match1.print_scoreboard())
print("=========================")
match1.add_over(5)
print("=========================")
match1.add_wicket(1)
print(match1.print_scoreboard())
# Out:
# 5..4..3..2..1.. Play !!!
# ...
# Batting Team: Rangpur Riders,
# Bowling Team: Cumilla Victorians
# Total Runs: 10 Wickets: 0 Overs: 1
# ...
# Warning! Cannot add 5 over/s (5 over match)
# ...
# Batting Team: Rangpur Riders,
# Bowling Team: Cumilla Victorians
# Total Runs: 10 Wickets: 1 Overs: 1

# %%
#TASK08
class ParcelKoro:
  def __init__(self,name = "NO NAME SET", product_weight = 0):
    self.name = name
    self.product_weight = product_weight
    self.fee = 0

  def calculateFee(self,loc = None):
    if loc == None:
      delivery = 50
    else:
      delivery = 100

    if self.name == "NO NAME SET":
      self.product_weight= 0
      self.fee = 0
    elif self.product_weight == 0:
      self.fee = 0
    elif self.name != "NO NAME SET" and  self.product_weight != 0:
      self.fee = (self.product_weight*20)+delivery

  def printDetails(self):
    print("Customer Name: ",self.name)
    print("Product Weight: ",self.product_weight)
    print("Total fee: ",self.fee)

print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer',10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name:  NO NAME SET
# Product Weight:  0
# Total fee:  0
# **********************
# Customer Name:  Bob The Builder
# Product Weight:  0
# Total fee:  0
# ----------------------------
# Customer Name:  Bob The Builder
# Product Weight:  15
# Total fee:  350
# **********************
# Customer Name:  Dora The Explorer
# Product Weight:  10
# Total fee:  300

# %%
#TASK09
class Batsman:
  def __init__(self,*args):
    if len(args) == 2:
      score , faced  = args
      self.name = "NEW BATSMAN"
    else:
      name, score, faced = args
      self.name = name

    self.score = score
    self.faced = faced

  def printCareerStatistics(self):
    print("Name: ",self.name)
    print("Runs Scored: ",self.score," Balls Faced: ",self.faced)

  def setName(self,name):
    self.name = name

  def battingStrikeRate(self):
    return (self.score/self.faced)*100

b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name:  NEW BATSMAN
# Runs Scored:  6101  Balls Faced:  7380
# ...
# Name:  Liton Das
# Runs Scored:  678  Balls Faced:  773
# ----------------------------
# 87.71021992238033
# ...
# Name:  Shakib Al Hasan
# Runs Scored:  6101  Balls Faced:  7380
# ----------------------------
# 82.66937669376694

# %%
#TASK10
class EPL_Team:
  def __init__(self,name,song = "NO SLOGAN"):
    self.name = name
    self.song = song
    self.title = 0

  def showClubInfo(self):
    return f"Name: {self.name} \nSong: {self.song} \nTotal No of title: {self.title}"

  def increaseTitle(self):
    self.title +=1

  def changeSong(self,new):
    self.song = new

manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# Out:
# ...
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 0
# ##################
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 1
# ...
# Name: Chelsea
# Song: None
# Total No of title: 0
# Name: Chelsea
# Song: Keep the blue flag flying high
# Total No of title: 0

# %%
#TASK11
class Author:
  def __init__(self,name = "Default",*args):
    self.name = name

    self.booklist =""
    if len(args)>0:
      for i in args:
        self.booklist +=i +"\n"

  def addBooks(self,*args):
    for i in args:
      self.booklist +=i + "\n"

  def changeName(self,new):
    self.name = new

  def printDetails(self):
    print("Author Name: ",self.name)
    print("--------")
    print("List of Books:")
    print(self.booklist)


auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name:  Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
#
# ...
# Default
# ...
# Author Name:  Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
#
# ...
# Author Name:  Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#TASK12
class TaxiLagbe:
  def __init__(self,num,area):
    self.num = num
    self.area = area
    self.count = 0
    self.name_list =[]
    self.fare_list =[]

  def addPassenger(self,*args):

    if self.count>3:
      print("Taxi Full! No more passengers can be added.")

    else:

      self.fare = 0

      for i in args:
        self.count+=1
        l = i.split("_")
        print(f"Dear {l[0]}! Welcome to TaxiLagbe.")
        self.name_list.append(l[0])
        self.fare_list.append(l[1])
      for i in self.fare_list:
        self.fare += int(i)



  def printDetails(self):
    print("Trip info for Taxi number: ",self.num)
    print(f"This taxi can cover only {self.area} area.")
    print("Total passengers: ",self.count)
    print("Passenger lists:")
    for i in self.name_list:
      if i == self.name_list[len(self.name_list)-1]:
        print(i)
      else:
        print(f"{i}, ",end="")

    print("Total collected fare: ",self.fare,"Taka")


taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200')
taxi1.addPassenger('Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115')
taxi2.addPassenger('Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number:  1010-01
# This taxi can cover only Dhaka area.
# Total passengers:  4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare:  505 Taka
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number:  1010-01
# This taxi can cover only Dhaka area.
# Total passengers:  4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare:  505 Taka
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number:  1010-02
# This taxi can cover only Khulna area.
# Total passengers:  2
# Passenger lists:
# Ronald, Parker
# ...

# %%
#TASK13
class Account:
  def __init__(self,name = "Default Account", balance = 0):
    self.name = name
    self.balance = balance

  def details(self):
    return f"{self.name}\n{self.balance}"

  def withdraw(self,amount):
    if self.balance - amount <3071:
      print("Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.")
    else:
      print("Withdraw successful! New balance is: ", self.balance - amount)

a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930)
print("------------------------")
a2.withdraw(600)
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is:  3071.0

# %%
#TASK14
class StudentDatabase:
  def __init__(self,name,Id):
    self.name = name
    self.Id = Id
    self.grades = {}

    avg = 0



  def calculateGPA(self,course,semester):
    self.one_sem = {}
    grade_list = []
    course_list = []
    total = 0
    l = []


    for i in course:
      l = i.split(":")
      course_list.append(l[0])
      grade_list.append(l[1])

    course_list = tuple(course_list)

    for i in range(len(grade_list)):
      grade_list[i] = grade_list[i].lstrip()
      grade_list[i] = float(grade_list[i])
      total += grade_list[i]

    avg = round(total/len(grade_list),2)


    self.one_sem[course_list] = avg
    self.grades[semester] = self.one_sem


  def printDetails(self):
    print("Name: ",self.name)
    print("Id: ",self.Id)
    for i in self.grades:
      print("Courses taken in ",i)
      for j in self.grades[i]:
        for k in j:
          print(k)
        print("GPA:",self.grades[i][j])


s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')
print(f'Grades for {s1.name}\n{s1.grades}')
print('------------------------------------------------------')
s1.printDetails()
s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
print('------------------------------------------------------')
print(f'Grades for {s2.name}\n{s2.grades}')
print('------------------------------------------------------')
s2.printDetails()
# Out:
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ------------------------------------------------------
# Name:  Pietro
# Id:  10101222
# Courses taken in  Summer2020
# CSE230
# CSE220
# MAT110
# GPA: 4.0
# Courses taken in  Summer2021
# CSE250
# CSE330
# GPA: 3.85
# ------------------------------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8}}
# ------------------------------------------------------
# Name:  Wanda
# Id:  10103332
# Courses taken in  Summer2022
# CSE111
# CSE260
# ENG101
# GPA: 3.8

# %%
#TASK20
class Student:
  def __init__(self,name = None, department = None):
    self.name = name
    self.department = department
    if name == None and department == None:
      print("Student name and department need to be set")
    elif department == None:
      print(f"Department for {name} needs to be set")
    elif department != None and name != None:
      print(f"{name} is from {department} department")

  def update_name(self,new_name):
    self.name = new_name
  def update_department(self,new_dep):
    self.department = new_dep
  def enroll(self,*args):
    self.courses = args
  def printDetail(self):
    print("Name: ",self.name)
    print("Department: ",self.department)
    print(f"{self.name} enrolled in {len(self.courses)} course(s)")
    for i in range(len(self.courses)):
      if i == len(self.courses)-1:
        print(self.courses[i],end = "")
      else:
        print(self.courses[i]+","+" ",end ="")
    print()


s1 = Student()
print("=========================")
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110", "MAT110", "ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set
# ...
# Jon is from EEE department
# ...
# ###########################
# Name:  Bob
# Department:  CSE
# Bob enrolled in 3 course(s)
# CSE110, MAT110, ENG091
# ...
# Name:  Carol
# Department:  BBA
# Carol enrolled in 1 course(s)
# BUS101
# ...
# Name:  Jon
# Department:  EEE
# Jon enrolled in 2 course(s)
# MAT110, PHY111

# %%
#TASK21
class Student:
  def __init__(self,name,Id,dept):
    self.name = name
    self.dept = dept
    self.Id = Id
  def details(self) :
    return (f"Name: {self.name} \nID: {self.Id} \nDepartment: {self.dept}")
  def advise(self,*args):
    status = ""
    credit = 3.0*(len(args))
    if credit<9.0:
      status = f"You have to take at least {(9.0-credit)//3} more course."
    elif credit>12.0:
      status = f"You have to drop at least {(credit-12.0)//3} course."
    elif 9.0<=credit<=12:
      status = "Ok"
    courses = ""
    for i in args:
      if i==args[len(args)-1]:
        courses+= i
      else:
        courses+=i+","+" "

    print(f"{self.name}, you have taken {credit} credits.")
    print("List of courses: ",courses)
    print("Status: ", status)

s1 = Student("Alice","20103012","CSE")
s2 = Student("Bob", "18301254","EEE")
s3 = Student("Carol", "17101238","CSE")
print("##########################")
print(s1.details())
print("##########################")
print(s2.details())
print("##########################")
s1.advise("CSE110", "MAT110", "PHY111")
print("##########################")
s2.advise("BUS101", "MAT120")
print("##########################")
s3.advise("MAT110", "PHY111", "ENG102",
"CSE111", "CSE230")
# Out:
# ##########################
# Name: Alice
# ID: 20103012
# Department: CSE
# ##########################
# Name: Bob
# ID: 18301254
# Department: EEE
# ##########################
# Alice, you have taken 9.0 credits.
# List of courses:  CSE110, MAT110, PHY111
# Status:  Ok
# ##########################
# Bob, you have taken 6.0 credits.
# List of courses:  BUS101, MAT120
# Status:  You have to take at least 1.0 more course.
# ##########################
# Carol, you have taken 15.0 credits.
# List of courses:  MAT110, PHY111, ENG102, CSE111, CSE230
# Status:  You have to drop at least 1.0 course.

# %%
#TASK22
class Hotel:
  def __init__(self,hotel):
    self.hotel = hotel
    self.stuffs = 0
    self.stuffdict = {}
    self.guests = 0
    self.guestdict = {}


  def addStuff(self,name=None,Age= None,Pn = "000"):
    self.name = name
    self.Age = Age
    self.Pn = Pn
    self.stuffs+=1
    self.stuffdict[self.stuffs] = [self.name,self.Age,self.Pn]
    print(f"Staff with ID {self.stuffs} is added")

  def getStuffById(self,ID):
    self.ID = ID
    for i in self.stuffdict:
      if i == self.ID:
        return f"Staff ID : {i}\nName : {self.stuffdict[i][0]}\nAge : {self.stuffdict[i][1]}\nPhone no :  {self.stuffdict[i][2]}"
  def allStaffs(self):
    print("All Staffs:")
    print('Number of Staff: ',self.stuffs)
    for i in range(1,self.stuffs+1):
      print(f"Staff ID: {i} Name:{self.stuffdict[i][0]} Age : {self.stuffdict[i][1]} Phone no :  {self.stuffdict[i][2]}")
  def addGuest(self,gname = None, gage = None, gnum = "000"):
    self.gname = gname
    self.gage = gage
    self.gnum = gnum
    self.guests+=1
    self.guestdict[self.guests] = [self.gname,self.gage,self.gnum]
    print(f"Guest with ID: {self.guests} is added")
  def getGuestById(self,gID):
    self.gID = gID
    for i in self.guestdict:
      if i == self.gID:
        return f"Guest ID : {i}\nName : {self.guestdict[i][0]}\nAge : {self.guestdict[i][1]}\nPhone no :  {self.guestdict[i][2]}"
  def allGuest(self):
    print("All Guests:")
    print('Number of Guests: ',self.guests)
    for i in range(1,self.guests+1):
      print(f"Guest ID: {i} Name:{self.guestdict[i][0]} Age : {self.guestdict[i][1]} Phone no :  {self.guestdict[i][2]}")


h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest("Carol",35,"123")
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, "431")
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# Staff with ID 1 is added
# ...
# Staff ID : 1
# Name : Adam
# Age : 26
# Phone no :  000
# ...
# Guest with ID: 1 is added
# ...
# Guest ID : 1
# Name : Carol
# Age : 35
# Phone no :  123
# ...
# Guest with ID: 2 is added
# ...
# Guest ID : 2
# Name : Diana
# Age : 32
# Phone no :  431
# ...
# All Staffs:
# Number of Staff:  1
# Staff ID: 1 Name:Adam Age : 26 Phone no :  000
# ...
# All Guests:
# Number of Guests:  2
# Guest ID: 1 Name:Carol Age : 35 Phone no :  123
# Guest ID: 2 Name:Diana Age : 32 Phone no :  431

# %%
#TASK23
class Author:
  def __init__(self,Aname = None):
    self.numbook = 0
    self.bookdict = {}
    self.name = Aname
  def setName(self,name = None):
    self.name = name
  def addBook(self,book,genre):
    if self.name == None:
      print("A book can not be added without author name")
    else:
      self.book = book
      self.genre = genre
      self.bookdict[self.genre] = self.book
      self.numbook +=1

  def printDetail(self):
    print(f"Number of Book(s): {self.numbook}\nAuthor Name: {self.name}")
    for i in self.bookdict:
      print(f"{i} : {self.bookdict[i]}")

a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book can not be added without author name
# ...
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction : Ice
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction : Onnobhubon
# Horror : Megher Upor Bari
# ...
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction : Ireena
# Horror : Megher Upor Bari
# ...

# %%
#TASK24

# %%
#BONUS
class Course:
  def __init__(self,name = None, num = None, place = None ):
    self.name = name
    self.num = num
    self.place = place

  def add_Courses(self,*args):
    course_list = []
    price_list = []
    self.total_price = 0
    self.courses = ""
    for i in args:
      l = i.split("-")
      course_list.append(l[0])
      price_list.append(l[1])
    for i in price_list:
      self.total_price+= int(i)
    for i in course_list:
      if i == course_list[len(course_list)-1]:
        self.courses +=i
      else:
        self.courses +=i+","+" "
  def createUser(self,*args):
    if len(args)==1:
      l = args[0].split("-")
      self.name = l[0]
      self.num = l[1]
      self.place = l[2]
    else:
      for i in args:
        k = i.split("-")
        break
      self.name = k[0]
      self.num = k[1]

  def printOrderDetail(self):
    print("Student's name:",self.name)
    print("Mobile no:",self.num)
    print("Location:",self.place)
    print("Total amount:",self.total_price)
    print("Purchased:",self.courses)

user1 = Course("Gamma", "01719658xxx", "Mohakhali")
user2 = Course()
user2.createUser("Intrudy-01719659xxx-Uttara")
user3 = Course("Foxtrot", "01719655xxx", "Mohammadpur")
user4 = Course()
user4.createUser("Menendez-01719660xxx","Mohakhali")
user1.add_Courses("CSE110-18000", "MAT110-15000")
user2.add_Courses("CSE111-18000")
user3.add_Courses("CSE220-20000")
user4.add_Courses("CSE221-25000")
print("1=========================")
user1.printOrderDetail()
print("2=========================")
user2.printOrderDetail()
print("3=========================")
user3.printOrderDetail()
print("4=========================")
user4.printOrderDetail()
print("5=========================")
print("Total amount: ", user1.total_price)
# Out:
# 1=========================
# Student's name: Gamma
# Mobile no: 01719658xxx
# Location: Mohakhali
# Total amount: 33000
# Purchased: CSE110, MAT110
# 2=========================
# Student's name: Intrudy
# Mobile no: 01719659xxx
# Location: Uttara
# Total amount: 18000
# Purchased: CSE111
# 3=========================
# Student's name: Foxtrot
# Mobile no: 01719655xxx
# Location: Mohammadpur
# Total amount: 20000
# Purchased: CSE220
# 4=========================
# Student's name: Menendez
# Mobile no: 01719660xxx
# Location: None
# Total amount: 25000
# Purchased: CSE221
# 5=========================
# Total amount:  33000

# %%
#EXTRA01
class Car:
  def __init__(self, name, year, Litre, Mode = "Manual"):
    self.name = name
    self.year = year
    self.Litre = Litre
    self.Mode = Mode

    print(f"{self.name} is created and the year is {self.year}")
    print(f"{self.name} has engine of {self.Litre}L with {self.Mode} gears")

  def addParts(self,*args):
    self.parts = args
    print(f"{len(args)} parts added to {self.name}")

  def showParts(self,count = 0):
    if count>len(self.parts):
      print(f"You do not have that many parts\nmax part is {len(self.parts)}")
    else:
      if count == 0:
        for i in range(1,len(self.parts)+1):
          print(f"{i}__{self.parts[i-1]}")
      else:
        for i in range(1,count+1):
          print(f"{i}__{self.parts[i-1]}")


c1=Car("Honda", 2012, 1.5)
print("--------------------")
c2=Car("Toyota", 2017, 1.7, "Auto")
print("--------------------")
c1.addParts("Turbo", "Radiator")
c2.addParts("BodyKit", "Radiator", "Air filter")
print("--------------------")
c1.showParts(5)
print("--------------------")
c1.showParts(1)
print("--------------------")
c2.showParts()
# Out:
# Honda is created and the year is 2012
# Honda has engine of 1.5L with Manual gears
# --------------------
# Toyota is created and the year is 2017
# Toyota has engine of 1.7L with Auto gears
# --------------------
# 2 parts added to Honda
# 3 parts added to Toyota
# --------------------
# You do not have that many parts
# max part is 2
# --------------------
# 1__Turbo
# --------------------
# 1__BodyKit
# 2__Radiator
# 3__Air filter

# %%
class msgClass:
    def __init__(self):
        self.content = 0
class Q5:
    def __init__(self):
        self.sum = 1
        self.x = 2
        self.y = 3
    def methodA(self):
        x, y = 1, 1
        msg = []
        myMsg = msgClass()
        myMsg.content = self.x
        msg.append(myMsg)
        msg[0].content = self.y + myMsg.content
        self.y = self.y + self.methodB(msg[0])
        y = self.methodB(msg[0]) + self.y
        x = y + self.methodB(msg[0], msg)
        self.sum = x + y + msg[0].content
        print(x," ", y," ", self.sum)

    def methodB(self, mg1, mg2 = None):
        if mg2 == None:
            x, y = 5, 6
            y = self.sum + mg1.content
            self.y = y + mg1.content
            x = self.x + 7 +mg1.content
            self.sum = self.sum + x + y
            self.x = mg1.content + x +8
            print(x, " ", y," ", self.sum)
            return y
        else:
            x = 1
            self.y += mg2[0].content
            mg2[0].content = self.y + mg1.content
            x = x + 4 + mg1.content
            self.sum += x + self.y
            mg1.content = self.sum - mg2[0].content
            print(self.x, " ",self.y," ", self.sum)
            return self.sum

q = Q5()
q.methodA()

# %%
def pasa(x,y):
  return x+y
pasa(7,8)
# Out:
# 15
